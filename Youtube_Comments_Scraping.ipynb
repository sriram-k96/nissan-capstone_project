# %%
from googleapiclient.discovery import build
import pandas as pd
pd.set_option('display.max_rows', 500)
api_key = 'ENTER API KEY' 
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
year_list = ['2022', '2023']
segmentdf = pd.read_excel('VehicleSegments.xlsx')
segmentdf.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
#Remove EVs to Optimize Youtube Queries
#Remove duplicated Grand Cherokee from Midsize SUV
seg2 = segmentdf.drop(segmentdf[(segmentdf['Model'] == 'Ariya') | (segmentdf['Model'] == 'Leaf') | (segmentdf['Model'] == 'C-hr') | (segmentdf['Model'] == 'Bz4x') | (segmentdf['Model'] == 'Bolt') | (segmentdf['Model'] == 'Ioniq') | (segmentdf['Model'] == 'Ioniq 5') | (segmentdf['Model'] == 'Ev6') | (segmentdf['Model'] == 'Nexo') | (segmentdf['Model'] == 'Ram') | (segmentdf['Model'] == 'R1t launch') | (segmentdf['Model'] == 'Endurance') | (segmentdf['Model'] == 'Solterra') | (segmentdf['Model'] == 'Mustang mach-e') | (segmentdf['Model'] == 'Hummer') | (segmentdf['Model'] == 'Id4')].index)
seg2 = seg2.drop(seg2[seg2['Model'] == 'Grand cherokee'].index[0])
seg2 = seg2.reset_index()
seg2.drop('index', axis = 1, inplace = True)

# %%
seg2["Make"].value_counts()
# Out:
# Nissan        14
# Toyota        13
# Chevrolet     11
# Ford          10
# Hyundai        9
# Honda          8
# Jeep           8
# Gmc            8
# Kia            8
# Volkswagen     7
# Subaru         6
# Mazda          6
# Buick          4
# Porsche        3
# Audi           2
# Mitsubishi     2
# Bmw            1
# Fiat           1
# Dodge          1
# Acura          1
# Name: Make, dtype: int64

# %%
#Youtube API per account cannot handle all models to be scraped at once. So they need to be segregated as shown below. 
#Safest way is to do it one at a time and then switch api key to different accounts.
#Use below code to systematically generate files as per make and then merge them in the end. 
segloc = seg2.loc[(seg2['Make'] == "Ford") | (seg2['Make'] == "Honda")]

# %%
query_list = []
for i in year_list:
    for j in segloc["Model"]:
        query = segloc.loc[segloc["Model"] == j]["Make"].tolist()[0] + ' ' + j + ' ' + str(i)
        query_list.append(query)

# %%
query_list
# Out:
# ['Honda Civic 2022',
#  'Honda Insight 2022',
#  'Honda Accord 2022',
#  'Ford Ecosport 2022',
#  'Honda Hr-v 2022',
#  'Ford Bronco 2022',
#  'Ford Edge 2022',
#  'Honda Passport 2022',
#  'Ford Explorer 2022',
#  'Honda Pilot 2022',
#  'Ford Expedition 2022',
#  'Ford Maverick 2022',
#  'Ford Ranger 2022',
#  'Honda Ridgeline 2022',
#  'Ford F series 2022',
#  'Ford Bronco sport 2022',
#  'Ford Escape 2022',
#  'Honda Cr-v 2022',
#  'Honda Civic 2023',
#  'Honda Insight 2023',
#  'Honda Accord 2023',
#  'Ford Ecosport 2023',
#  'Honda Hr-v 2023',
#  'Ford Bronco 2023',
#  'Ford Edge 2023',
#  'Honda Passport 2023',
#  'Ford Explorer 2023',
#  'Honda Pilot 2023',
#  'Ford Expedition 2023',
#  'Ford Maverick 2023',
#  'Ford Ranger 2023',
#  'Honda Ridgeline 2023',
#  'Ford F series 2023',
#  'Ford Bronco sport 2023',
#  'Ford Escape 2023',
#  'Honda Cr-v 2023']

# %%
len(query_list)
# Out:
# 36

# %%
#Can be used to get the list of URLs to be scraped - Choose ones with maximum comments to maintain efficiency of queries. 
#But this process is incredibly intensive on the quota and has to be used sparingly. 
#Hence a combination of this and manual process of searching and grabbing URLs directly from youtube were used. 
#Scaling this requires permission from Google which can be done by 
#the organization if required through increasing Quota limits substantially. 10000 points per day is inadequate. 
#Only 2022 and 2023 will be considered here due to query limits
urls = []
for i in query_list:
    search_response = youtube.search().list(q=i, part='id,snippet', maxResults=5).execute()
    video_ids = [search_result['id']['videoId'] for search_result in search_response.get('items', [])]
    video_response = youtube.videos().list(id=','.join(video_ids), part='id,snippet,statistics').execute()
    try:
        for video_result in video_response.get('items', []):
            title = video_result['snippet']['title']
            url = f'https://www.youtube.com/watch?v={video_result["id"]}'
            video_id = video_result["id"]
            view_count = video_result['statistics']['viewCount']
            comment_count = video_result['statistics']['commentCount']
            urls.append((i, title, url, video_id, view_count, comment_count))
    except:
        print(i)
        continue
yturl_df = pd.DataFrame(urls, columns = ['Query', 'Title', 'URL', 'VideoID', 'ViewCount', 'Comment_Count'])

# %%
yturl_df['Comment_Count'] = yturl_df['Comment_Count'].astype(int)
#Taking only the top result by comments. Due to a large number of vehicles over 2 years, this needs to be done to stay within query limits
yturl_df_top = yturl_df.groupby('Query').apply(lambda x: x.nlargest(5, 'Comment_Count')).reset_index(drop=True)
#Removing duplicate results - Sometimes same results come up as top results for similar queries - Unpopular vehicles for both year queries for instance
#Needs to be done to avoid duplicating scraping. 
yturl_df_top = yturl_df_top.drop(yturl_df_top[yturl_df_top.drop('Query', axis = 1).duplicated()].index)

# %%
yturl_df_top
# Out:
#                       Query  \
# 0          Ford Bronco 2022
# 1          Ford Bronco 2022
# 2          Ford Bronco 2022
# 3          Ford Bronco 2022
# 4          Ford Bronco 2022
# 5          Ford Bronco 2023
# 6          Ford Bronco 2023
# 7          Ford Bronco 2023
# 8          Ford Bronco 2023
# 9          Ford Bronco 2023
# 11   Ford Bronco sport 2022
# 12   Ford Bronco sport 2022
# 13   Ford Bronco sport 2022
# 14   Ford Bronco sport 2022
# 15   Ford Bronco sport 2023
# 16   Ford Bronco sport 2023
# 17   Ford Bronco sport 2023
# 18   Ford Bronco sport 2023
# 19   Ford Bronco sport 2023
# 20       Ford Ecosport 2022
# 21       Ford Ecosport 2022
# 22       Ford Ecosport 2022
# 23       Ford Ecosport 2022
# 24       Ford Ecosport 2022
# 25       Ford Ecosport 2023
# 26       Ford Ecosport 2023
# 27       Ford Ecosport 2023
# 28       Ford Ecosport 2023
# 29       Ford Ecosport 2023
# 30           Ford Edge 2022
# 31           Ford Edge 2022
# 32           Ford Edge 2022
# 33           Ford Edge 2022
# 34           Ford Edge 2022
# 35           Ford Edge 2023
# 36           Ford Edge 2023
# 37           Ford Edge 2023
# 38           Ford Edge 2023
# 39           Ford Edge 2023
# 40         Ford Escape 2022
# 41         Ford Escape 2022
# 42         Ford Escape 2022
# 43         Ford Escape 2022
# 44         Ford Escape 2022
# 45         Ford Escape 2023
# 46         Ford Escape 2023
# 47         Ford Escape 2023
# 48         Ford Escape 2023
# 49         Ford Escape 2023
# 50     Ford Expedition 2022
# 51     Ford Expedition 2022
# 52     Ford Expedition 2022
# 53     Ford Expedition 2022
# 54     Ford Expedition 2022
# 55     Ford Expedition 2023
# 56     Ford Expedition 2023
# 57     Ford Expedition 2023
# 58     Ford Expedition 2023
# 59     Ford Expedition 2023
# 60       Ford Explorer 2022
# 61       Ford Explorer 2022
# 62       Ford Explorer 2022
# 63       Ford Explorer 2022
# 64       Ford Explorer 2022
# 65       Ford Explorer 2023
# 66       Ford Explorer 2023
# 67       Ford Explorer 2023
# 68       Ford Explorer 2023
# 69       Ford Explorer 2023
# 70       Ford F series 2022
# 71       Ford F series 2022
# 72       Ford F series 2022
# 73       Ford F series 2022
# 74       Ford F series 2022
# 76       Ford F series 2023
# 77       Ford F series 2023
# 78       Ford F series 2023
# 79       Ford F series 2023
# 80       Ford Maverick 2022
# 81       Ford Maverick 2022
# 82       Ford Maverick 2022
# 83       Ford Maverick 2022
# 84       Ford Maverick 2022
# 85       Ford Maverick 2023
# 86       Ford Maverick 2023
# 87       Ford Maverick 2023
# 88       Ford Maverick 2023
# 89       Ford Maverick 2023
# 90         Ford Ranger 2022
# 91         Ford Ranger 2022
# 92         Ford Ranger 2022
# 93         Ford Ranger 2022
# 94         Ford Ranger 2022
# 95         Ford Ranger 2023
# 96         Ford Ranger 2023
# 97         Ford Ranger 2023
# 98         Ford Ranger 2023
# 99         Ford Ranger 2023
# 100       Honda Accord 2022
# 101       Honda Accord 2022
# 102       Honda Accord 2022
# 103       Honda Accord 2022
# 104       Honda Accord 2022
# 105       Honda Accord 2023
# 106       Honda Accord 2023
# 107       Honda Accord 2023
# 108       Honda Accord 2023
# 109       Honda Accord 2023
# 110        Honda Civic 2022
# 111        Honda Civic 2022
# 112        Honda Civic 2022
# 113        Honda Civic 2022
# 114        Honda Civic 2022
# 115        Honda Civic 2023
# 116        Honda Civic 2023
# 117        Honda Civic 2023
# 118        Honda Civic 2023
# 119        Honda Civic 2023
# 120         Honda Cr-v 2022
# 121         Honda Cr-v 2022
# 122         Honda Cr-v 2022
# 123         Honda Cr-v 2022
# 124         Honda Cr-v 2022
# 125         Honda Cr-v 2023
# 126         Honda Cr-v 2023
# 127         Honda Cr-v 2023
# 128         Honda Cr-v 2023
# 129         Honda Cr-v 2023
# 130         Honda Hr-v 2022
# 131         Honda Hr-v 2022
# 132         Honda Hr-v 2022
# 133         Honda Hr-v 2022
# 134         Honda Hr-v 2022
# 135         Honda Hr-v 2023
# 136         Honda Hr-v 2023
# 137         Honda Hr-v 2023
# 138         Honda Hr-v 2023
# 140      Honda Insight 2022
# 141      Honda Insight 2022
# 142      Honda Insight 2022
# 143      Honda Insight 2022
# 144      Honda Insight 2022
# 147      Honda Insight 2023
# 148      Honda Insight 2023
# 149      Honda Insight 2023
# 150     Honda Passport 2022
# 151     Honda Passport 2022
# 152     Honda Passport 2022
# 153     Honda Passport 2022
# 154     Honda Passport 2022
# 155     Honda Passport 2023
# 156     Honda Passport 2023
# 157     Honda Passport 2023
# 158     Honda Passport 2023
# 159     Honda Passport 2023
# 160        Honda Pilot 2022
# 161        Honda Pilot 2022
# 162        Honda Pilot 2022
# 163        Honda Pilot 2022
# 164        Honda Pilot 2022
# 165        Honda Pilot 2023
# 166        Honda Pilot 2023
# 167        Honda Pilot 2023
# 168        Honda Pilot 2023
# 169        Honda Pilot 2023
# 170    Honda Ridgeline 2022
# 171    Honda Ridgeline 2022
# 172    Honda Ridgeline 2022
# 173    Honda Ridgeline 2022
# 174    Honda Ridgeline 2022
# 176    Honda Ridgeline 2023
# 177    Honda Ridgeline 2023
# 178    Honda Ridgeline 2023
# 179    Honda Ridgeline 2023
#
#                                                  Title  \
# 0    2022 Ford Bronco Raptor - interior Exterior De...
# 1    Is the 2022 Ford Wildtrak the Bronco trim that...
# 2    2022 Ford Bronco Raptor - POV Driving Impressions
# 3    2022 Ford Bronco Sport // The Affordable Bronc...
# 4    2022 Ford Bronco review // Eats huge bumps for...
# 5    Is the 2023 Ford Bronco Raptor the best NEW pe...
# 6    6 Reasons to Buy a 2023 Ford Bronco (What's New?)
# 7                   OFF-ROAD 4x4 Test 2023 Ford BRONCO
# 8    2023 Ford Bronco Wildtrak (HOSS 3.0 Fox Shocks...
# 9    2023 Ford Bronco Badlands Manual: Start Up, Te...
# 11                     2022 Ford Bronco Sport Big Bend
# 12   2022 Ford Bronco Sport Outer Banks - REVIEW an...
# 13   2022 Ford Bronco Sport Badlands: Is This A Rea...
# 14   2022 Ford Bronco Sport Review: Is it Really a ...
# 15   2023 Ford Bronco Sport Heritage: Wow As Expens...
# 16   2023 Bronco Sport Big Bend: TEST DRIVE+FULL RE...
# 17   The 2023 Ford Bronco Sport Badlands is still t...
# 18   2023 Ford Bronco Sport Badlands: When You Can'...
# 19            2023 Ford Bronco Sport Review and prices
# 20   Is the 2020 Ford EcoSport a subcompact SUV wor...
# 21   2022 Ford EcoSport ACTIVE with LED Headlights ...
# 22   2022 Ford EcoSport 4WD: Did Ford Make A Mistak...
# 23                 NEW FORD Ecosport Active 2022 IN 4K
# 24   2022 Ford Ecosport Titanium + NAV, Moonroof, A...
# 25   2023 Ford EcoSport Active Price Review | Cost ...
# 26                                  Ford EcoSport 2023
# 27   2023 Ford Ecosport Ttitanium 2.0L($29,690) - I...
# 28   The End of EcoSport? Titanium, Active 2023 For...
# 29   2023 Ford EcoSport - 2023 Ford EcoSport Redesi...
# 30     2022 Ford Edge Review, It Sucks, It’s A Fat Pig
# 31   5 Reasons Why You Should Buy A 2022 Ford Edge ...
# 32   2022 Ford Edge ST: Is This A Great Performance...
# 33   2022 Ford Edge SEL Review - Walk Around and Te...
# 34   2022 Ford Edge Full Review: Does It Still Stac...
# 35                  The 2023 Ford Edge ST is excellent
# 36            2023 Ford Edge L SUV in-depth Walkaround
# 37   2023 - 2024 New Ford Edge - Shows Off New Styling
# 38                    2023 Ford Edge L Best Family SUV
# 39   2023 Ford Edge ST Line Review! Exterior, Inter...
# 40   2022 Ford Escape Stealth: WOW! This Escape Is ...
# 41   2022 Ford Escape SE 1.5L FWD - POV Review and ...
# 42   2022 Ford Escape Review | Nicer Than You'd Expect
# 43   2022 Ford Escape SEL: Is This The Best Package...
# 44   2022 Ford Escape Titanium: Best Compact Crosso...
# 45   Is the 2023 Ford Escape a better SUV than the ...
# 46   2023 Ford Escape ST-Line – Redline: First Look...
# 47   2023 Ford Escape: Updated Looks, Bigger Screen...
# 48           ALL NEW 2023 FORD ESCAPE INTERIOR LOOK!!!
# 49   FORD ESCAPE 2023 Facelift - FULL in-depth REVI...
# 50   The 2022 Ford Expedition Stealth Performance h...
# 51          2022 Ford Expedition | MotorWeek Road Test
# 52   The 2022 Ford Expedition XLT Max Is A Nicely U...
# 53   2022 Ford Expedition Platinum - POV Driving Im...
# 54   2022 Ford Expedition Review | Extra-large perf...
# 55    2023 Ford Expedition Platinum: Is This Worth It?
# 56   2023 Ford Expedition Stealth Performance: Is T...
# 57   NEW 2023 FORD EXPEDITION PLATINUM: Nicest Luxu...
# 58   2023 Ford Expedition Limited: TEST DRIVE+FULL ...
# 59                       2023 Ford Expedition Platinum
# 60   2022 Ford Explorer Timberline AWD Review and S...
# 61   Is the 2022 Ford Explorer ST a BETTER performa...
# 62   2022 Ford Explorer ST // Anything NEW for this...
# 63           Watch Before You Buy a 2022 Ford Explorer
# 64   2022 Ford Explorer XLT Review - Walk Around an...
# 65   New 2023 Ford Explorer - Redesigned Practical ...
# 66   2023 Ford Explorer ST // Any CHANGES to this *...
# 67   Ford Explorer 2023 in-depth Walkaround Interio...
# 68   2023 Ford Explorer Platinum: This Is A Great L...
# 69      2023 Ford Explorer New Interior and Walkaround
# 70                2022 Ford F150 | The Truck Perfected
# 71   2023 Ford F-150 Raptor Black - interior and Ex...
# 72                       2022 Ford F-150 Tremor Review
# 73   2022 Ford F-150 XLT Black Appearance: Woah! Th...
# 74   2022 Ford F-150 STX // Is This the BEST F-150 ...
# 76            DELETED FEATURES! 2023 Ford F-150 Review
# 77   2023 Ford F-150 Raptor R - POV First Impressio...
# 78   2023 Ford F-Series Super Duty Trucks -  Next-L...
# 79   2023 Ford F-Series Super Duty Truck Revealed (...
# 80   2022 Ford Maverick Full Review: an Affordable,...
# 81   The 2022 Ford Maverick Hybrid is the BEST Smal...
# 82   Is the 2022 Ford Maverick a BETTER new truck t...
# 83    2022 Ford Maverick review: Ultimate nerd machine
# 84   Everything To Know About The 2022 Ford Maveric...
# 85   The 2023 Ford Maverick Tremor Adds Off-Road Ca...
# 86   2023 Ford Maverick | For People Who Never Knew...
# 87   Say GOODBYE to the 2023 Ford Maverick, Here's Why
# 88                           2023 Ford Maverick Tremor
# 89   2023 Ford Maverick Review - This is the Truck ...
# 90   Is the NEW 2021 Ford Ranger Tremor a better tr...
# 91   2022 Ford Ranger - Driving, Exterior and inter...
# 92   2022 Ford Ranger Lariat Tremor: Better Than A ...
# 93   2022 Ford Ranger XLT SuperCrew | Learn all abo...
# 94   2022 Ford Ranger XLT FX4: Does The Ranger Need...
# 95   Here's Why You SHOULD NOT Buy The New 2023 For...
# 96                             FORD RANGER 2023 review
# 97   2023 Ford Ranger SuperCrew | Learn all about t...
# 98   10 Things You Need To Know Before Buying The 2...
# 99   2023 Ford Ranger XLT 2.3T POV Test Drive & Review
# 100  2022 Honda Civic vs Honda Accord - Worth the $...
# 101  2022 Honda Accord // Is This Still a Mid-Size ...
# 102  The 2022 Honda Accord Sport 2.0T is the Reason...
# 103  2022 Honda Accord - interior and Exterior Deta...
# 104             2022 Honda Accord FULL DETAILED REVIEW
# 105  2023 Honda Accord Touring Review // You Can’t ...
# 106  Is the NEW 2023 Honda Accord Touring a sedan W...
# 107  Is the 2023 Honda Accord EX the BEST new midsi...
# 108                          WHY!? | 2023 Honda Accord
# 109  New Honda Accord (2023) – Features & Overview ...
# 110  The 2022 Honda Civic Is the New Version of Eve...
# 111           Is this best new car? Honda Civic review
# 112            2022 Honda Civic Review // Compact King
# 113        2022 Honda Civic Touring Sedan - POV Review
# 114  2022 Honda Civic Sport // The #1 Selling Civic...
# 115  Is the 2023 Honda Civic Hatchback a BETTER car...
# 116  2023 Honda Civic Review || Almost Perfect Exce...
# 117  2023 Honda Civic Sedan // Is this the #1 Compa...
# 118                     2023 Honda Civic - Perfect Car
# 119                      2023 Honda Civic Sport Review
# 120  2022 Honda CR-V // Still a GREAT Option for 2022!
# 121                  2022 Honda CR-V EX Review & Drive
# 122     2022 Honda CR-V - Still An Amazing Compact SUV
# 123     2022 Honda CR-V - Exterior and interior design
# 124             Watch Before You Buy A 2022 Honda CR-V
# 125  Is the 2023 Honda CR-V a BETTER compact SUV to...
# 126        2023 Honda CR-V Hybrid | Review & Road Test
# 127            👉 2023 Honda CR-V EX-L -- Detailed Look
# 128  New HONDA CR-V 2023 - FULL in-depth REVIEW (ex...
# 129  2023 Honda CR-V Hybrid Sport - Is It The BEST ...
# 130                             Honda HR-V 2022 Review
# 131                   2022 Honda HR-V - Wonderful SUV!
# 132               2023 Honda HR-V | Review & Road Test
# 133  This 2022 Honda HR-V EX Has A Feature ALL Hond...
# 134  2022 Honda HR-V - Interior and Exterior Detail...
# 135  The 2023 Honda HR-V Is a Rational, Normal Litt...
# 136  Is the NEW 2023 Honda HR-V Sport a redesigned ...
# 137          RIP COROLLA CROSS! 2023 Honda HR-V Review
# 138  The 2023 Honda HR-V EX-L AWD Is An Affordably ...
# 140              2022 Honda Insight Review | 55 MPG's!
# 141  👉 2022 Honda Insight Touring - Ultimate In-Dep...
# 142  2022 Honda Insight Touring / Best Hybrid Price...
# 143  2022 Honda Insight Touring: Is This Better Tha...
# 144  2022 Honda Insight EX - Is It The BEST Hybrid ...
# 147     2023 Honda Insight Hybrid All You Need To Know
# 148                             New 2023 Honda Insight
# 149  2023 Honda Insight Redesign - Revealed Specs P...
# 150  Is the 2022 Honda Passport Trailsport a better...
# 151  The 2022 Honda Passport Trailsport Is A More R...
# 152  2022 Honda Passport Elite // Is this the UPDAT...
# 153  2022 Honda Passport TrailSport | MotorWeek Roa...
# 154        2022 Honda Passport Test Drive Video Review
# 155  2023 Honda Passport TrailSport: Toyotas Are Ov...
# 156  2023 Honda Passport EX-L - The ULTIMATE In-Dep...
# 157        2023 Honda Passport TRAILSPORT Off-Road SUV
# 158             2023 Honda CR-V VS 2023 Honda Passport
# 159                      2023 Honda Passport AWD Elite
# 160  Is the 2022 Honda Pilot Black Edition a better...
# 161  2022 Honda Pilot // Do 2022 Updates Keep the P...
# 162                2022 Honda Pilot EXL | CAR MOM TOUR
# 163  2022 Honda Pilot EX-L: Is The Entry Level Pack...
# 164  New 2022 Honda Pilot (Premium 3 Row SUV) - Ful...
# 165  Is the 2023 Honda Pilot a new midsize SUV wort...
# 166                            2023 Honda Pilot Review
# 167  2023 Honda Pilot TrailSport | MotorWeek Road Test
# 168   ALL-NEW 2023 Honda Pilot Is The BEST Pilot EVER!
# 169      2023 Honda Pilot review - Cleared for takeoff
# 170        2022 Honda Ridgeline | Family Pickup Review
# 171  2022 Honda Ridgeline RTL-E - A GREAT Multitask...
# 172        Watch Before You Buy A 2022 Honda Ridgeline
# 173  2022 Honda Ridgeline is it actually worth buying?
# 174   2023 Honda Ridgeline RTL - The Gentleman's Truck
# 176  2023 Honda Ridgeline - A GREAT Multitasking Tr...
# 177  2023 Honda Ridgeline Black Edition: All Specs ...
# 178  2023 Honda Ridgeline RTL - Is It The ULTIMATE ...
# 179  2023 Honda Ridgeline WALKAROUND   All You Need...
#
#                                              URL      VideoID ViewCount  \
# 0    https://www.youtube.com/watch?v=zH3zaUvwcv4  zH3zaUvwcv4   1944390
# 1    https://www.youtube.com/watch?v=0k2YT6dsrp4  0k2YT6dsrp4    107153
# 2    https://www.youtube.com/watch?v=t_5Zx2IB48Q  t_5Zx2IB48Q    407351
# 3    https://www.youtube.com/watch?v=DWvQN5_EqC0  DWvQN5_EqC0    258516
# 4    https://www.youtube.com/watch?v=iVcgYBhT3E4  iVcgYBhT3E4     75597
# 5    https://www.youtube.com/watch?v=LlDG_-ilagg  LlDG_-ilagg     81836
# 6    https://www.youtube.com/watch?v=8V46N_2almY  8V46N_2almY    151407
# 7    https://www.youtube.com/watch?v=qK20jhZShSE  qK20jhZShSE    169556
# 8    https://www.youtube.com/watch?v=7Zwf-H3LTmo  7Zwf-H3LTmo     45970
# 9    https://www.youtube.com/watch?v=A5ANU7C7TgA  A5ANU7C7TgA      1535
# 11   https://www.youtube.com/watch?v=TNFJ78eOKc4  TNFJ78eOKc4     43753
# 12   https://www.youtube.com/watch?v=FFeMpp-GQbs  FFeMpp-GQbs     16095
# 13   https://www.youtube.com/watch?v=k0E0UqZB6DQ  k0E0UqZB6DQ     22211
# 14   https://www.youtube.com/watch?v=t_0tOdFe4Y8  t_0tOdFe4Y8     20539
# 15   https://www.youtube.com/watch?v=hRjGRZiiqPI  hRjGRZiiqPI     13590
# 16   https://www.youtube.com/watch?v=9llRK9AioDI  9llRK9AioDI     22376
# 17   https://www.youtube.com/watch?v=LX-WBvhakRI  LX-WBvhakRI     15917
# 18   https://www.youtube.com/watch?v=l7Ymssk-d_E  l7Ymssk-d_E      9412
# 19   https://www.youtube.com/watch?v=EapoHpaIaQw  EapoHpaIaQw      5747
# 20   https://www.youtube.com/watch?v=VcOoduTCSig  VcOoduTCSig    119806
# 21   https://www.youtube.com/watch?v=vLuB-gT2rco  vLuB-gT2rco    195874
# 22   https://www.youtube.com/watch?v=hNNhWVrGgs0  hNNhWVrGgs0     18809
# 23   https://www.youtube.com/watch?v=O-deSWhtRCc  O-deSWhtRCc     56308
# 24   https://www.youtube.com/watch?v=EuuKt0T5tJk  EuuKt0T5tJk     18609
# 25   https://www.youtube.com/watch?v=1J_xyGQ92h0  1J_xyGQ92h0     23058
# 26   https://www.youtube.com/watch?v=iVh1H41wcNA  iVh1H41wcNA    131815
# 27   https://www.youtube.com/watch?v=J6aMHZxiqsQ  J6aMHZxiqsQ    113184
# 28   https://www.youtube.com/watch?v=amE7L6_4sAc  amE7L6_4sAc     10829
# 29   https://www.youtube.com/watch?v=AsdByUgc6sM  AsdByUgc6sM     13437
# 30   https://www.youtube.com/watch?v=CL_FW8thDkg  CL_FW8thDkg      9300
# 31   https://www.youtube.com/watch?v=Hy1umCdWoCY  Hy1umCdWoCY     44000
# 32   https://www.youtube.com/watch?v=X-j7aSda-HU  X-j7aSda-HU     38800
# 33   https://www.youtube.com/watch?v=f_s-886pDBM  f_s-886pDBM     28673
# 34   https://www.youtube.com/watch?v=tzQY_qPXF0w  tzQY_qPXF0w      7578
# 35   https://www.youtube.com/watch?v=BmIVGAOycVM  BmIVGAOycVM     22694
# 36   https://www.youtube.com/watch?v=8q21zh-aVpA  8q21zh-aVpA     57688
# 37   https://www.youtube.com/watch?v=deG24GbTxzI  deG24GbTxzI      7319
# 38   https://www.youtube.com/watch?v=eUCJt9os84Y  eUCJt9os84Y      8907
# 39   https://www.youtube.com/watch?v=vkQZ5kEmY_g  vkQZ5kEmY_g      5938
# 40   https://www.youtube.com/watch?v=go6Fp9ztyrg  go6Fp9ztyrg     14109
# 41   https://www.youtube.com/watch?v=aliwLf7bLYw  aliwLf7bLYw     11315
# 42   https://www.youtube.com/watch?v=6VzCywBhtS4  6VzCywBhtS4     27234
# 43   https://www.youtube.com/watch?v=6mHg-TqUuq8  6mHg-TqUuq8     13408
# 44   https://www.youtube.com/watch?v=ui_-6MOD-v8  ui_-6MOD-v8      3615
# 45   https://www.youtube.com/watch?v=vmfjqUtO96g  vmfjqUtO96g    170801
# 46   https://www.youtube.com/watch?v=aWN-Q2jYYYE  aWN-Q2jYYYE    106364
# 47   https://www.youtube.com/watch?v=6nIffkaISQI  6nIffkaISQI     77379
# 48   https://www.youtube.com/watch?v=39tj1n-YoWM  39tj1n-YoWM      1399
# 49   https://www.youtube.com/watch?v=2P75wqUQX10  2P75wqUQX10     13546
# 50   https://www.youtube.com/watch?v=d8lVDVQaKKA  d8lVDVQaKKA    429825
# 51   https://www.youtube.com/watch?v=rNvPvbFDZFY  rNvPvbFDZFY     33917
# 52   https://www.youtube.com/watch?v=qCiIE_ka5tU  qCiIE_ka5tU     83770
# 53   https://www.youtube.com/watch?v=6uJkpHUkzJ0  6uJkpHUkzJ0    256291
# 54   https://www.youtube.com/watch?v=8kp_S7yJraI  8kp_S7yJraI     13500
# 55   https://www.youtube.com/watch?v=UZDBsCbBNgE  UZDBsCbBNgE      6244
# 56   https://www.youtube.com/watch?v=ZsmQcjAsnnI  ZsmQcjAsnnI     29413
# 57   https://www.youtube.com/watch?v=DNOEuj273WM  DNOEuj273WM     18790
# 58   https://www.youtube.com/watch?v=-DwJwQ7AJF8  -DwJwQ7AJF8      9518
# 59   https://www.youtube.com/watch?v=_bjVBKv1u6E  _bjVBKv1u6E       830
# 60   https://www.youtube.com/watch?v=xpOhU-KdYyw  xpOhU-KdYyw    435781
# 61   https://www.youtube.com/watch?v=jtHr4dMEdtE  jtHr4dMEdtE    188147
# 62   https://www.youtube.com/watch?v=zLJeK_P6XI0  zLJeK_P6XI0    352048
# 63   https://www.youtube.com/watch?v=kBmXlt8rr2Y  kBmXlt8rr2Y     41357
# 64   https://www.youtube.com/watch?v=EDAS6DwxQYU  EDAS6DwxQYU     11393
# 65   https://www.youtube.com/watch?v=gMc66uG80BE  gMc66uG80BE    822623
# 66   https://www.youtube.com/watch?v=W46muHMSsTM  W46muHMSsTM     45627
# 67   https://www.youtube.com/watch?v=Sna9LyFy8XY  Sna9LyFy8XY    285420
# 68   https://www.youtube.com/watch?v=W-Q5y6frams  W-Q5y6frams     53936
# 69   https://www.youtube.com/watch?v=jilhnybc81A  jilhnybc81A     83238
# 70   https://www.youtube.com/watch?v=xlQT-6Rcjrk  xlQT-6Rcjrk    339785
# 71   https://www.youtube.com/watch?v=jVo6PcBzBvA  jVo6PcBzBvA   3266826
# 72   https://www.youtube.com/watch?v=-YXJZFQ0Z70  -YXJZFQ0Z70    320014
# 73   https://www.youtube.com/watch?v=5fWtTGwRWcc  5fWtTGwRWcc     90321
# 74   https://www.youtube.com/watch?v=wSYNSXlL4bQ  wSYNSXlL4bQ     75601
# 76   https://www.youtube.com/watch?v=l-3TLe2VJ2c  l-3TLe2VJ2c    109735
# 77   https://www.youtube.com/watch?v=Xd61eIZtRLU  Xd61eIZtRLU    131049
# 78   https://www.youtube.com/watch?v=vjdQbo2EuOw  vjdQbo2EuOw    328589
# 79   https://www.youtube.com/watch?v=7HD1rTkIXVA  7HD1rTkIXVA      9449
# 80   https://www.youtube.com/watch?v=ocHFC03Wmbw  ocHFC03Wmbw   1691024
# 81   https://www.youtube.com/watch?v=YkgA8pUrf_w  YkgA8pUrf_w    324500
# 82   https://www.youtube.com/watch?v=SE5CR2r7GO4  SE5CR2r7GO4    115390
# 83   https://www.youtube.com/watch?v=6tNl8l0h9Tk  6tNl8l0h9Tk    188355
# 84   https://www.youtube.com/watch?v=GkCXjZhm21o  GkCXjZhm21o     27495
# 85   https://www.youtube.com/watch?v=9975ovD5PNY  9975ovD5PNY    315995
# 86   https://www.youtube.com/watch?v=3ylLHkLYxyg  3ylLHkLYxyg     47962
# 87   https://www.youtube.com/watch?v=Zk6JVYGKQYM  Zk6JVYGKQYM    122385
# 88   https://www.youtube.com/watch?v=uNn_qo_pl_M  uNn_qo_pl_M     69214
# 89   https://www.youtube.com/watch?v=m-7zeGAA4lc  m-7zeGAA4lc     42889
# 90   https://www.youtube.com/watch?v=Xhr3rVZG7Z0  Xhr3rVZG7Z0    105635
# 91   https://www.youtube.com/watch?v=Dlw5J4G6A6w  Dlw5J4G6A6w    590343
# 92   https://www.youtube.com/watch?v=EpMHWwFTBSw  EpMHWwFTBSw     83064
# 93   https://www.youtube.com/watch?v=5zSaPB3tMYI  5zSaPB3tMYI     28865
# 94   https://www.youtube.com/watch?v=OlToA5xnnsE  OlToA5xnnsE     50766
# 95   https://www.youtube.com/watch?v=oSpe7JW6gvM  oSpe7JW6gvM    541438
# 96   https://www.youtube.com/watch?v=la7kOGAr4qk  la7kOGAr4qk     69852
# 97   https://www.youtube.com/watch?v=lEP8FA6TWkI  lEP8FA6TWkI      9634
# 98   https://www.youtube.com/watch?v=o00gyTaX0vc  o00gyTaX0vc     17316
# 99   https://www.youtube.com/watch?v=nG4lwINXjZQ  nG4lwINXjZQ      3945
# 100  https://www.youtube.com/watch?v=rJcP9EmuTqs  rJcP9EmuTqs   2467842
# 101  https://www.youtube.com/watch?v=UquyG6Cst9k  UquyG6Cst9k    517030
# 102  https://www.youtube.com/watch?v=TmihZPj0Vlg  TmihZPj0Vlg    281611
# 103  https://www.youtube.com/watch?v=IBaodKjVKOk  IBaodKjVKOk    994246
# 104  https://www.youtube.com/watch?v=sA3q2xDXaQM  sA3q2xDXaQM    170883
# 105  https://www.youtube.com/watch?v=MdMvGQdI3qU  MdMvGQdI3qU    642865
# 106  https://www.youtube.com/watch?v=puJwhMW4rwY  puJwhMW4rwY    178836
# 107  https://www.youtube.com/watch?v=_IqcjJln-7o  _IqcjJln-7o     66806
# 108  https://www.youtube.com/watch?v=FMXabALbQ5A  FMXabALbQ5A      4294
# 109  https://www.youtube.com/watch?v=ma7CHRnifZI  ma7CHRnifZI      3328
# 110  https://www.youtube.com/watch?v=LZfxJbd0_E4  LZfxJbd0_E4   1193595
# 111  https://www.youtube.com/watch?v=L9_xKVwVkso  L9_xKVwVkso   1712064
# 112  https://www.youtube.com/watch?v=QWDmK93hIOc  QWDmK93hIOc   1819255
# 113  https://www.youtube.com/watch?v=GaWJ3cXFETo  GaWJ3cXFETo   1110647
# 114  https://www.youtube.com/watch?v=MOa3b5O56S0  MOa3b5O56S0    516537
# 115  https://www.youtube.com/watch?v=veRJX2Jk0ts  veRJX2Jk0ts     62012
# 116  https://www.youtube.com/watch?v=-VlAHYBl54M  -VlAHYBl54M    118194
# 117  https://www.youtube.com/watch?v=q28n6-ITkp4  q28n6-ITkp4    102070
# 118  https://www.youtube.com/watch?v=y8Y0sWi6BSA  y8Y0sWi6BSA    427545
# 119  https://www.youtube.com/watch?v=T5KDcFcGVEk  T5KDcFcGVEk      5896
# 120  https://www.youtube.com/watch?v=It48Yzn5kX8  It48Yzn5kX8    381833
# 121  https://www.youtube.com/watch?v=3Vq52vsUDWg  3Vq52vsUDWg    195125
# 122  https://www.youtube.com/watch?v=qOvNhJIOKMQ  qOvNhJIOKMQ     76391
# 123  https://www.youtube.com/watch?v=2MaXSjd5peU  2MaXSjd5peU    349578
# 124  https://www.youtube.com/watch?v=UPSliyk5eMc  UPSliyk5eMc     15192
# 125  https://www.youtube.com/watch?v=PG9XL9hTyeM  PG9XL9hTyeM    104126
# 126  https://www.youtube.com/watch?v=QiPT4s_HSH8  QiPT4s_HSH8    321740
# 127  https://www.youtube.com/watch?v=ZP9ZKwQoVXo  ZP9ZKwQoVXo    306676
# 128  https://www.youtube.com/watch?v=aAIlX_Elf3s  aAIlX_Elf3s    529029
# 129  https://www.youtube.com/watch?v=-8P2tce0lfs  -8P2tce0lfs     26773
# 130  https://www.youtube.com/watch?v=MVwJmYYBUMc  MVwJmYYBUMc   1670163
# 131  https://www.youtube.com/watch?v=umbwyjLd_7o  umbwyjLd_7o   5325001
# 132  https://www.youtube.com/watch?v=blYj8HmGqfc  blYj8HmGqfc    167436
# 133  https://www.youtube.com/watch?v=kg6oEiFXJ6g  kg6oEiFXJ6g     80310
# 134  https://www.youtube.com/watch?v=Zg7Fs-yiLXU  Zg7Fs-yiLXU    285402
# 135  https://www.youtube.com/watch?v=HUwLG7gNmYU  HUwLG7gNmYU    278646
# 136  https://www.youtube.com/watch?v=maiv140grIw  maiv140grIw    274058
# 137  https://www.youtube.com/watch?v=4uzhN9dxAy8  4uzhN9dxAy8    303036
# 138  https://www.youtube.com/watch?v=L-LlaFDvIYo  L-LlaFDvIYo     91459
# 140  https://www.youtube.com/watch?v=ph0ncVc0T5A  ph0ncVc0T5A    163994
# 141  https://www.youtube.com/watch?v=vaDYeWLj7EE  vaDYeWLj7EE     93678
# 142  https://www.youtube.com/watch?v=7UB-M25CNCs  7UB-M25CNCs     31861
# 143  https://www.youtube.com/watch?v=0V86H3mI3Po  0V86H3mI3Po     37710
# 144  https://www.youtube.com/watch?v=1RiE_Nqi1hE  1RiE_Nqi1hE     13533
# 147  https://www.youtube.com/watch?v=wB7rlxlAYsk  wB7rlxlAYsk      4297
# 148  https://www.youtube.com/watch?v=pPKM5nQfMHk  pPKM5nQfMHk      3075
# 149  https://www.youtube.com/watch?v=V9ZL4VKLurw  V9ZL4VKLurw      3069
# 150  https://www.youtube.com/watch?v=TjPvxOMFvh0  TjPvxOMFvh0    104677
# 151  https://www.youtube.com/watch?v=WpCnT4Y_D2o  WpCnT4Y_D2o    176263
# 152  https://www.youtube.com/watch?v=f2C_OPqaYYQ  f2C_OPqaYYQ    186009
# 153  https://www.youtube.com/watch?v=ykTquyTLB0Y  ykTquyTLB0Y     53307
# 154  https://www.youtube.com/watch?v=AUZtl2l0Bt4  AUZtl2l0Bt4     35020
# 155  https://www.youtube.com/watch?v=FNVSFq9ErQc  FNVSFq9ErQc     44285
# 156  https://www.youtube.com/watch?v=u310jXvjqPo  u310jXvjqPo     40751
# 157  https://www.youtube.com/watch?v=LvcwMCeYpoY  LvcwMCeYpoY     43211
# 158  https://www.youtube.com/watch?v=csLorJxVJoQ  csLorJxVJoQ     21923
# 159  https://www.youtube.com/watch?v=hD9xXhfWwxw  hD9xXhfWwxw     10176
# 160  https://www.youtube.com/watch?v=5GhqclVU-so  5GhqclVU-so    209013
# 161  https://www.youtube.com/watch?v=Zc5JDhXGONc  Zc5JDhXGONc    217685
# 162  https://www.youtube.com/watch?v=syGsu8k1U7E  syGsu8k1U7E    116590
# 163  https://www.youtube.com/watch?v=DHSkIsJNA3w  DHSkIsJNA3w     47517
# 164  https://www.youtube.com/watch?v=9nNUdP93WMs  9nNUdP93WMs     49093
# 165  https://www.youtube.com/watch?v=wgHiXL93m8U  wgHiXL93m8U    153819
# 166  https://www.youtube.com/watch?v=PoNRoL9Y_nc  PoNRoL9Y_nc    100936
# 167  https://www.youtube.com/watch?v=IRo4gptE4GI  IRo4gptE4GI     17468
# 168  https://www.youtube.com/watch?v=nT5KV15sXlQ  nT5KV15sXlQ      4364
# 169  https://www.youtube.com/watch?v=BJssDOm9SZo  BJssDOm9SZo       227
# 170  https://www.youtube.com/watch?v=YgpJw4wc9d0  YgpJw4wc9d0    131440
# 171  https://www.youtube.com/watch?v=WmsNiOF06f8  WmsNiOF06f8     55930
# 172  https://www.youtube.com/watch?v=xMdc8zvEzwA  xMdc8zvEzwA     61305
# 173  https://www.youtube.com/watch?v=D0jL8uevw-k  D0jL8uevw-k     50451
# 174  https://www.youtube.com/watch?v=HGhfexCRgBw  HGhfexCRgBw     76628
# 176  https://www.youtube.com/watch?v=qbA5fh6xyaQ  qbA5fh6xyaQ     38967
# 177  https://www.youtube.com/watch?v=Y516ywmmPJo  Y516ywmmPJo     25222
# 178  https://www.youtube.com/watch?v=hZsprXLKk-M  hZsprXLKk-M     13616
# 179  https://www.youtube.com/watch?v=oV-n1SnxZ0E  oV-n1SnxZ0E     19982
#
#      Comment_Count
# 0              414
# 1              353
# 2              340
# 3              236
# 4              162
# 5              322
# 6              299
# 7              114
# 8               58
# 9               15
# 11              73
# 12              41
# 13              30
# 14              25
# 15              61
# 16              44
# 17              43
# 18              26
# 19               2
# 20             646
# 21              90
# 22              83
# 23              41
# 24               8
# 25             129
# 26              85
# 27              34
# 28               9
# 29               5
# 30             106
# 31              51
# 32              48
# 33              38
# 34              11
# 35             124
# 36              17
# 37               9
# 38               9
# 39               7
# 40              57
# 41              32
# 42              19
# 43              14
# 44               3
# 45             526
# 46             322
# 47              93
# 48               9
# 49               7
# 50             650
# 51             222
# 52             216
# 53             210
# 54              29
# 55              60
# 56              51
# 57              33
# 58              24
# 59               3
# 60             879
# 61             661
# 62             327
# 63              77
# 64              12
# 65             159
# 66             155
# 67              88
# 68              74
# 69              30
# 70            1062
# 71             748
# 72             612
# 73             137
# 74             128
# 76             544
# 77             175
# 78              49
# 79              15
# 80            5981
# 81             730
# 82             677
# 83             173
# 84              29
# 85            1392
# 86             325
# 87             259
# 88             173
# 89             127
# 90             561
# 91             195
# 92             123
# 93              87
# 94              71
# 95             934
# 96             409
# 97              35
# 98              10
# 99              10
# 100           2181
# 101            523
# 102            394
# 103            181
# 104            173
# 105           2822
# 106           1154
# 107            590
# 108             55
# 109              4
# 110           4900
# 111           3483
# 112           3067
# 113           1282
# 114            725
# 115            464
# 116            329
# 117            191
# 118            146
# 119             19
# 120            303
# 121            222
# 122             64
# 123             38
# 124             30
# 125            493
# 126            326
# 127            120
# 128             98
# 129             39
# 130           2496
# 131           1467
# 132            262
# 133            183
# 134             48
# 135           1518
# 136            911
# 137            739
# 138            363
# 140            264
# 141            170
# 142             92
# 143             47
# 144             36
# 147              1
# 148              1
# 149              0
# 150            493
# 151            315
# 152            222
# 153            127
# 154             35
# 155             80
# 156             74
# 157             69
# 158             44
# 159             24
# 160            765
# 161            220
# 162            211
# 163             46
# 164              6
# 165            793
# 166            233
# 167             52
# 168             21
# 169              2
# 170            330
# 171            161
# 172            154
# 173            149
# 174            127
# 176            124
# 177             89
# 178             41
# 179              8

# %%
replies = []
comments = []
#commcount = 0
for vid in yturl_df_top['VideoID']:
    video_response=youtube.commentThreads().list(part='snippet,replies',videoId=vid).execute()
    model = yturl_df_top.loc[yturl_df_top["VideoID"] == vid]["Query"].tolist()[0]
    #for q, w in video_ids_dict.items():
    #    if vid in [p for p in w]:
    #        model = q
    url = 'https://www.youtube.com/watch?v='+vid
    title = yturl_df_top.loc[yturl_df_top["VideoID"] == vid]["Title"].tolist()[0]
    #title_response = youtube.videos().list(part='snippet',id=vid).execute()
    #title = title_response['items'][0]['snippet']['title']
    while video_response:
        #extraction based on nested dictionary structure of the video_response object
        for item in video_response['items']:
            #Comment Extraction
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            #Replies of a comment
            replycount = item['snippet']['totalReplyCount']
            try:
                if replycount>0:
                    for reply in item['replies']['comments']:
                    # Extract reply
                        reply = reply['snippet']['textDisplay']
                        replies.append(reply)
            except:
                print('Reply Err')
 
            #Display Comments and Corresponding Replies
            if replies == list():
                replies = "None"
            #print(commcount)
            comments.append((model, comment, replies, title, url))
            #commcount = commcount + 1
            #print(comment)
            replies = []
 
            #"Pagination"/Show More 
        if 'nextPageToken' in video_response:
            video_response = youtube.commentThreads().list(part = 'snippet,replies',videoId = vid, 
                                                           pageToken = video_response['nextPageToken']).execute()
        else:
            break

# %%
df = pd.DataFrame(comments, columns = ['Model', 'Comments', 'Replies', 'Video Title', 'URL'])

# %%
df.to_csv('YoutubeComments.csv')

# %% [raw]
# #These files were generated one at a time.
# df1 = pd.read_csv('YoutubeCommentsHyundai_Kia.csv')
# df2 = pd.read_csv('YoutubeCommentsFord_Honda.csv')
# df3 = pd.read_csv('YoutubeCommentsToyota.csv')
# df4 = pd.read_csv('YoutubeCommentsNissan.csv')
# df5 = pd.read_csv('YoutubeCommentsBuick_Porsche_Gmc.csv')
# df6 = pd.read_csv('YoutubeCommentsVolkswagen.csv')
# df7 = pd.read_csv('YoutubeCommentsChevrolet.csv')
# df8 = pd.read_csv('YoutubeCommentsSubaru_Mazda.csv')
# df9 = pd.read_csv('YoutubeCommentsLast6Make.csv')
# df10 = pd.read_csv('YoutubeCommentsJeep.csv')
# df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10]).reset_index()
# df.drop(['index', 'Unnamed: 0'], axis = 1, inplace = True)
# df.to_csv('YoutubeComments.csv')

# %%
df = pd.read_csv('YoutubeComments.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
df['Make'] = df['Model'].str.split().str.get(0)
df['Year'] = df['Model'].str.split().str.get(2)
df['Model'] = df['Model'].str.split().str.get(1)
df2 = pd.read_excel('VehicleSegments.xlsx')
df2.drop('Unnamed: 0', axis = 1, inplace = True)
df_full = pd.merge(df, df2, on = ["Make", "Model"])
df_full = df_full[['Segment', 'Make', 'Model', 'Year', 'Comments', 'Replies', 'Video Title', 'URL']]
df_full['Word Count'] = df_full['Comments'].str.split(' ').str.len()

# %%
df_full.to_csv('YoutubeCommentsFull.csv')

# %%
df_full.head()
# Out:
#    Segment     Make    Model  Year  \
# 0  Compact  Hyundai  Elantra  2022
# 1  Compact  Hyundai  Elantra  2022
# 2  Compact  Hyundai  Elantra  2022
# 3  Compact  Hyundai  Elantra  2022
# 4  Compact  Hyundai  Elantra  2022
#
#                                             Comments  \
# 0                         They stepped up there game
# 1  the way he says N HAHAHAHAHAHAHAH you can feel...
# 2  I like how no one accepts the fact that the el...
# 3  Nothing makes me happier than the disappointed...
# 4  I need help Hyundai Elantra n or dodge charger...
#
#                                              Replies  \
# 0                                               None
# 1                                               None
# 2  ['@A Dude That Play&#39;s Games Ifkr they shar...
# 3                                               None
# 4                                               None
#
#                                          Video Title  \
# 0  The 2022 Hyundai Elantra N Is a Surprisingly S...
# 1  The 2022 Hyundai Elantra N Is a Surprisingly S...
# 2  The 2022 Hyundai Elantra N Is a Surprisingly S...
# 3  The 2022 Hyundai Elantra N Is a Surprisingly S...
# 4  The 2022 Hyundai Elantra N Is a Surprisingly S...
#
#                                            URL  Word Count
# 0  https://www.youtube.com/watch?v=nn2-7jMkSGs           5
# 1  https://www.youtube.com/watch?v=nn2-7jMkSGs          11
# 2  https://www.youtube.com/watch?v=nn2-7jMkSGs          42
# 3  https://www.youtube.com/watch?v=nn2-7jMkSGs          17
# 4  https://www.youtube.com/watch?v=nn2-7jMkSGs          10

# %%
dfe = pd.read_csv('Edmunds_CustomerReviews.csv', encoding = "utf-16")

# %%
l = dfe['Review'].str.split().str.len().tolist()
avg_edmunds_reviewlength = sum(l)/len(l)

# %%
df_final = df_full.loc[df_full["Word Count"] > 40].reset_index()
df_final.drop('index', axis = 1, inplace = True)
df_final = df_final.drop_duplicates()
df_final.to_csv('YoutubeComments_40_InfoRich.csv')

# %%
df_final['Make'].value_counts()
# Out:
# Nissan        4592
# Toyota        4342
# Mazda         2588
# Honda         2578
# Chevrolet     2062
# Ford          1793
# Kia           1630
# Hyundai       1589
# Volkswagen    1193
# Gmc           1140
# Subaru        1057
# Acura          652
# Porsche        557
# Jeep           528
# Audi           285
# Mitsubishi     278
# Buick          151
# Dodge           90
# Bmw             38
# Fiat            22
# Name: Make, dtype: int64

# %% [raw]
# DEBUG
# Check if all replies which are list of lists + comments add up to total comments in the YT Video.
# [len(i) for i in list(df.loc[df["Replies"] != 'None']['Replies'])]
