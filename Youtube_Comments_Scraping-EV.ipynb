# %%
from googleapiclient.discovery import build
import pandas as pd
pd.set_option('display.max_rows', 500)
api_key = 'ENTER API KEY'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
year_list = ['2022', '2023']
segmentdf = pd.read_excel('EV_VehicleSegments.xlsx')
segmentdf.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
seg2 = segmentdf

# %%
seg2['Make'].unique()
# Out:
# array(['Audi', 'Bmw', 'Cadillac', 'Genesis', 'Jaguar', 'Lucid',
#        'Mercedes-benz', 'Polestar', 'Porsche', 'Rivian', 'Tesla', 'Volvo',
#        'Chevrolet', 'Ford', 'Gmc', 'Hyundai', 'Kia', 'Mazda', 'Mini',
#        'Nissan', 'Subaru', 'Toyota', 'Volkswagen'], dtype=object)

# %%
#Youtube API per account cannot handle all models to be scraped at once. So they need to be segregated as shown below. 
#Safest way is to do it a few at a time and then switch api key to different accounts.
#Use below code to systematically generate files as per make and then merge them in the end. 
segloc = seg2.loc[(seg2['Make'] == "Nissan") | (seg2['Make'] == "Tesla")]

# %%
query_list = []
for i in year_list:
    for j in segloc["Model"]:
        query = segloc.loc[segloc["Model"] == j]["Make"].tolist()[0] + ' ' + j + ' ' + str(i)
        query_list.append(query)

# %%
query_list
# Out:
# ['Tesla Model 3 2022',
#  'Tesla Model s 2022',
#  'Tesla Model x 2022',
#  'Tesla Model y 2022',
#  'Nissan Ariya 2022',
#  'Nissan Leaf 2022',
#  'Tesla Model 3 2023',
#  'Tesla Model s 2023',
#  'Tesla Model x 2023',
#  'Tesla Model y 2023',
#  'Nissan Ariya 2023',
#  'Nissan Leaf 2023']

# %%
len(query_list)
# Out:
# 12

# %%
#Can be used to get the list of URLs to be scraped - Choose ones with maximum comments to maintain efficiency of queries. 
#But this process is incredibly intensive on the quota and has to be used sparingly. 
#Hence a combination of this and manual process of searching and grabbing URLs directly from youtube were used. 
#Scaling this requires permission from Google which can be done by 
#the organization if required through increasing Quota limits substantially. 10000 points per day is inadequate. 
#Only 2022 and 2023 will be considered here due to query limits
urls = []
for i in query_list:
    search_response = youtube.search().list(q=i, part='id,snippet', maxResults=8).execute()
    video_ids = [search_result['id']['videoId'] for search_result in search_response.get('items', [])]
    video_response = youtube.videos().list(id=','.join(video_ids), part='id,snippet,statistics').execute()
    try:
        for video_result in video_response.get('items', []):
            title = video_result['snippet']['title']
            url = f'https://www.youtube.com/watch?v={video_result["id"]}'
            video_id = video_result["id"]
            view_count = video_result['statistics']['viewCount']
            comment_count = video_result['statistics']['commentCount']
            urls.append((i, title, url, video_id, view_count, comment_count))
    except:
        print(i)
        continue
yturl_df = pd.DataFrame(urls, columns = ['Query', 'Title', 'URL', 'VideoID', 'ViewCount', 'Comment_Count'])
# Out:
# Nissan Ariya 2022
# Tesla Model s 2023

# %%
yturl_df['Comment_Count'] = yturl_df['Comment_Count'].astype(int)
#Taking only the top result by comments. Due to a large number of vehicles over 2 years, this needs to be done to stay within query limits
yturl_df_top = yturl_df.groupby('Query').apply(lambda x: x.nlargest(8, 'Comment_Count')).reset_index(drop=True)
#Removing duplicate results - Sometimes same results come up as top results for similar queries - Unpopular vehicles for both year queries for instance
# 40  Tesla Model 3 2023  HUGE Announcement! - New SECRET Discount! | Te...
# 41  Tesla Model 3 2023  2023 Tesla Model 3 3 Months Later - Is it Wort...
# 42  Tesla Model 3 2023  ALL NEW 2023 Tesla Model 3 SHOCKS The Entire C...
# 43  Tesla Model s 2022  Is the 2022 Tesla Model S Plaid the KING of pe...
# 44  Tesla Model s 2022        New Tesla Model S Plaid Test Drive POV 2023
# 45  Tesla Model s 2022  2022 Tesla Model S Long Range AWD POV Test Dri...
# 46  Tesla Model s 2022  2022 Tesla Model S Plaid // So Fast it HURTS!....
# 47  Tesla Model s 2022  2022 Tesla Model S HONEST REVIEW. 5 Month Review.
# 48  Tesla Model s 2022  2022 Tesla Model S Delivery - Test Drive, Ligh...
# 49  Tesla Model s 2022  2022 Tesla Model S Long Range - Exterior and I...
# 50  Tesla Model s 2022  2022 Tesla Model S - interior and Exterior Det...
# 52  Tesla Model s 2023  Tesla Model S Long Range 2023 - FULL Review in...
# 53  Tesla Model s 2023  2023 Tesla Model S - Exterior and interior det...
# 54  Tesla Model s 2023  Do NOT Buy the 2023 Tesla Model S Dual Motor AWD!
# 55  Tesla Model s 2023  First Look: 2023 Model S Ultra Red Delivery - ...
# 56  Tesla Model s 2023     2023 Tesla Model S Refresh Test Drive & Review
# 57  Tesla Model s 2023  The New 2023 Tesla Model S Update is Finally Here
# 58  Tesla Model x 2022  The 2022 Tesla Model X Plaid Is an Insanely Fa...
# 59  Tesla Model x 2022  2022 Tesla Model X Plaid Review // Six Seat Su...
# 60  Tesla Model x 2022               2022 Tesla Model X Long Range Review
# 61  Tesla Model x 2022     2022 Tesla Model X Facelift - Walkaround in 4k
# 62  Tesla Model x 2022  Tesla Model X Plaid Interior, And Review Updat...
# 63  Tesla Model x 2022         Tesla Model X 2023 Thoughts After 3 Months
# 64  Tesla Model x 2022  2022 Tesla Model X Six Months Later Review: Be...
# 65  Tesla Model x 2022  Tesla Model X 6 Months Later Review | Still th...
# 66  Tesla Model x 2023  Tesla Model X Refresh: 1 Month Later - Is It B...
# 67  Tesla Model x 2023               2023 Tesla Model X - Why we upgraded
# 70  Tesla Model x 2023                    Tesla Model X Plaid Review 2023
# 71  Tesla Model x 2023  2023 Tesla Model X Plaid Review | New Cameras ...
# 72  Tesla Model x 2023    Tesla Model X Plaid 2023 Interior And New Guide
# 73  Tesla Model x 2023   The NEW 2023 Tesla Model X! The Premium Tesla...
# 74  Tesla Model y 2022  Tesla Model Y 2022 review - the BEST electric ...
# 75  Tesla Model y 2022     NEW 2023 Tesla Model Y Compared to Old Model Y
# 76  Tesla Model y 2022                2022 Tesla Model Y - 3 Months Later
# 77  Tesla Model y 2022     2023 Tesla Model Y Review With All New Updates
# 78  Tesla Model y 2022  2022 Tesla Model Y - interior and Exterior Det...
# 79  Tesla Model y 2022  2023 Tesla Model Y Performance Review | 2022 M...
# 80  Tesla Model y 2022  2023 Tesla Model Y Long Range: Is This The Tes...
# 81  Tesla Model y 2022  2022 Tesla Model Y Review | The Electric SUV B...
# 70  https://www.youtube.com/watch?v=GzxriGbesew  GzxriGbesew     24360
# 71  https://www.youtube.com/watch?v=DCEzO7DpTT4  DCEzO7DpTT4     27440
# 72  https://www.youtube.com/watch?v=UvVk7ZTh5us  UvVk7ZTh5us     10455
# 73  https://www.youtube.com/watch?v=yOZ2Lepyl94  yOZ2Lepyl94     12675
# 74  https://www.youtube.com/watch?v=PZ8NPeYFPCY  PZ8NPeYFPCY   1797867
# 75  https://www.youtube.com/watch?v=081cM9b6J98  081cM9b6J98    285457
# 76  https://www.youtube.com/watch?v=qz5y-Jkwdso  qz5y-Jkwdso     37579
# 77  https://www.youtube.com/watch?v=G8JSwNwXu9A  G8JSwNwXu9A    312984
# 78  https://www.youtube.com/watch?v=jwwWjkbV-kM  jwwWjkbV-kM    281062
# 79  https://www.youtube.com/watch?v=ZBtyMAiWEf0  ZBtyMAiWEf0     93033
# 80  https://www.youtube.com/watch?v=mPlVSkedyQI  mPlVSkedyQI     56628
# 81  https://www.youtube.com/watch?v=WCKlLGnMfKs  WCKlLGnMfKs     95361
# 83  https://www.youtube.com/watch?v=B9kFpDgARgM  B9kFpDgARgM     27179
# 85  https://www.youtube.com/watch?v=dB2xlPK_ttg  dB2xlPK_ttg     19744
# 86  https://www.youtube.com/watch?v=CFmFaQ6azYI  CFmFaQ6azYI     39162
# 87  https://www.youtube.com/watch?v=xXh-Xaldu6c  xXh-Xaldu6c     10358
# 88  https://www.youtube.com/watch?v=m9rZ5WOZ9o0  m9rZ5WOZ9o0     27439
# 89  https://www.youtube.com/watch?v=6DJjeXtWrfc  6DJjeXtWrfc       845
#
#     Comment_Count
# 0            2265
# 1            1455
# 2             391
# 4             393
# 5             319
# 6             251
# 7             111
# 8              28
# 9              15
# 10              4
# 11            693
# 12            347
# 13            169
# 14            108
# 15             76
# 16             70
# 17             59
# 18             13
# 20            120
# 22             78
# 23             12
# 24             10
# 25              7
# 26              2
# 27            558
# 28            342
# 29            320
# 30            252
# 31            247
# 32            117
# 33            110
# 34            108
# 38             92
# 39             65
# 40             29
# 41             26
# 42             20
# 43            941
# 44            164
# 45            144
# 46            122
# 47             56
# 48             55
# 49             26
# 50              8
# 52             37
# 53             27
# 54             22
# 55             18
# 56              6
# 57              4
# 58           4549
# 59           2331
# 60            106
# 61             88
# 62             71
# 63             63
# 64             56
# 65             52
# 66            231
# 67            212
# 70             49
# 71             23
# 72              9
# 73              6
# 74           2816
# 75            342
# 76            185
# 77            168
# 78            114
# 79             97
# 80             86
# 81             85
# 83            153
# 85             53
# 86             40
# 87             19
# 88             11
# 89              1

# %%
replies = []
comments = []
#commcount = 0
for vid in yturl_df_top['VideoID']:
    video_response=youtube.commentThreads().list(part='snippet,replies',videoId=vid).execute()
    model = yturl_df_top.loc[yturl_df_top["VideoID"] == vid]["Query"].tolist()[0]
    #for q, w in video_ids_dict.items():
    #    if vid in [p for p in w]:
    #        model = q
    url = 'https://www.youtube.com/watch?v='+vid
    title = yturl_df_top.loc[yturl_df_top["VideoID"] == vid]["Title"].tolist()[0]
    #title_response = youtube.videos().list(part='snippet',id=vid).execute()
    #title = title_response['items'][0]['snippet']['title']
    while video_response:
        #extraction based on nested dictionary structure of the video_response object
        for item in video_response['items']:
            #Comment Extraction
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            #Replies of a comment
            replycount = item['snippet']['totalReplyCount']
            try:
                if replycount>0:
                    for reply in item['replies']['comments']:
                    # Extract reply
                        reply = reply['snippet']['textDisplay']
                        replies.append(reply)
            except:
                print('Reply Err')
 
            #Display Comments and Corresponding Replies
            if replies == list():
                replies = "None"
            #print(commcount)
            comments.append((model, comment, replies, title, url))
            #commcount = commcount + 1
            #print(comment)
            replies = []
 
            #"Pagination"/Show More 
        if 'nextPageToken' in video_response:
            video_response = youtube.commentThreads().list(part = 'snippet,replies',videoId = vid, 
                                                           pageToken = video_response['nextPageToken']).execute()
        else:
            break

# %%
df = pd.DataFrame(comments, columns = ['Model', 'Comments', 'Replies', 'Video Title', 'URL'])

# %%
df.to_csv('YoutubeComments_EV_Nissan_Tesla_Large.csv')

# %%
df
# Out:
#                     Model                                           Comments  \
# 0       Nissan Ariya 2022  <a href="https://www.youtube.com/watch?v=hbykc...
# 1       Nissan Ariya 2022                    More from this guy. Subscribed!
# 2       Nissan Ariya 2022             Will this be available in south Africa
# 3       Nissan Ariya 2022  And take off the big fluffy jacket while drivi...
# 4       Nissan Ariya 2022  I&#39;m surprised at how you manage to make a ...
# ...                   ...                                                ...
# 13642  Tesla Model y 2023             shit man thas a huge pile of shit talk
# 13643  Tesla Model y 2023                                    Truck Electric?
# 13644  Tesla Model y 2023                                  I love it ❤❤🎉🎉🎉🎉🎉
# 13645  Tesla Model y 2023  We that live in northern Scandinavia for exemp...
# 13646  Tesla Model y 2023                                               🏆🏆🏆🏆
#
#                                                  Replies  \
# 0      [Actually, IMHO, all mentioned cars look bette...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 13642                                               None
# 13643                                               None
# 13644                                               None
# 13645                                               None
# 13646                                               None
#
#                                              Video Title  \
# 0           Nissan Ariya review - it changes everything!
# 1           Nissan Ariya review - it changes everything!
# 2           Nissan Ariya review - it changes everything!
# 3           Nissan Ariya review - it changes everything!
# 4           Nissan Ariya review - it changes everything!
# ...                                                  ...
# 13642  Tesla Model Y 2023 Update Is Here And SHOCKS E...
# 13643  Tesla Model Y 2023 Update Is Here And SHOCKS E...
# 13644  Tesla Model Y 2023 Update Is Here And SHOCKS E...
# 13645  Tesla Model Y 2023 Update Is Here And SHOCKS E...
# 13646  2023 Tesla Model Y Update Is FINALLY Here & SH...
#
#                                                URL
# 0      https://www.youtube.com/watch?v=hbykcnRP3Rc
# 1      https://www.youtube.com/watch?v=hbykcnRP3Rc
# 2      https://www.youtube.com/watch?v=hbykcnRP3Rc
# 3      https://www.youtube.com/watch?v=hbykcnRP3Rc
# 4      https://www.youtube.com/watch?v=hbykcnRP3Rc
# ...                                            ...
# 13642  https://www.youtube.com/watch?v=m9rZ5WOZ9o0
# 13643  https://www.youtube.com/watch?v=m9rZ5WOZ9o0
# 13644  https://www.youtube.com/watch?v=m9rZ5WOZ9o0
# 13645  https://www.youtube.com/watch?v=m9rZ5WOZ9o0
# 13646  https://www.youtube.com/watch?v=6DJjeXtWrfc
#
# [13647 rows x 5 columns]

# %%
#These files were generated one at a time. 
df1 = pd.read_csv('YoutubeComments_EV_First7.csv')
df2 = pd.read_csv('YoutubeComments_EV_8to14.csv')
df3 = pd.read_csv('YoutubeComments_EV_15to21.csv')
df4 = pd.read_csv('YoutubeComments_EV_Last2.csv')
#df5 = pd.read_csv('YoutubeComments_EV_Tesla.csv')
df6 = pd.read_csv('YoutubeComments_EV_Mini.csv')
df7 = pd.read_csv('YoutubeComments_EV_Porsche_Ford_Hyundai.csv')
df8 = pd.read_csv('YoutubeComments_EV_Nissan_Tesla_Large.csv')

df = pd.concat([df1, df2, df3, df4, df8, df6, df7]).reset_index()
df.drop(['index', 'Unnamed: 0'], axis = 1, inplace = True)
df = df.drop_duplicates()
df.to_csv('YoutubeComments_EV.csv')

# %%
df = pd.read_csv('YoutubeComments_EV.csv')
df.drop('Unnamed: 0', axis = 1, inplace = True)
df['Make'] = df['Model'].str.split().str.get(0)
#if len(df['Model'].str.split())
df['Year'] = df['Model'].str.split().str.get(-1)
#This is needed due to Models having 2 or more words in their name. The years are then removed.
df['Model'] = df['Model'].str.split().str[1:4].apply(lambda x: ' '.join(x))
df['Model'] = df['Model'].str.replace('2022', '')
df['Model'] = df['Model'].str.replace('2023', '')
df['Model'] = df['Model'].str.strip()
df2 = pd.read_excel('EV_VehicleSegments.xlsx')
df2.drop('Unnamed: 0', axis = 1, inplace = True)
df_full = pd.merge(df, df2, on = ["Make", "Model"])
df_full = df_full[['Segment', 'Make', 'Model', 'Year', 'Comments', 'Replies', 'Video Title', 'URL']]
df_full['Word Count'] = df_full['Comments'].str.split(' ').str.len()

# %%
df_full.to_csv('YoutubeCommentsFull_EV.csv')

# %%
df_full['Make'].value_counts()
# Out:
# Lucid            20664
# Mercedes-benz    19296
# Bmw              17372
# Ford             14799
# Rivian           13115
# Tesla             9873
# Hyundai           9070
# Audi              9000
# Gmc               8608
# Kia               8376
# Polestar          5913
# Genesis           5362
# Cadillac          5119
# Mazda             4689
# Nissan            4329
# Toyota            3905
# Chevrolet         3124
# Subaru            2772
# Volvo             2603
# Jaguar             843
# Volkswagen         626
# Porsche            430
# Mini               417
# Name: Make, dtype: int64

# %%
dfe = pd.read_csv('Edmunds_CustomerReviews.csv', encoding = "utf-16")

# %%
l = dfe['Review'].str.split().str.len().tolist()
avg_edmunds_reviewlength = sum(l)/len(l)

# %%
df_final = df_full.loc[df_full["Word Count"] > 40].reset_index()
df_final.drop('index', axis = 1, inplace = True)
df_final = df_final.drop_duplicates()
df_final.to_csv('YoutubeComments_40_InfoRich_EV.csv')

# %%
df_final
# Out:
#           Segment        Make   Model  Year  \
# 0          Luxury        Audi  E-tron  2022
# 1          Luxury        Audi  E-tron  2022
# 2          Luxury        Audi  E-tron  2022
# 3          Luxury        Audi  E-tron  2022
# 4          Luxury        Audi  E-tron  2022
# ...           ...         ...     ...   ...
# 17716  Non-Luxury  Volkswagen     Id4  2023
# 17717  Non-Luxury  Volkswagen     Id4  2023
# 17718  Non-Luxury  Volkswagen     Id4  2023
# 17719  Non-Luxury  Volkswagen     Id4  2023
# 17720  Non-Luxury  Volkswagen     Id4  2023
#
#                                                 Comments  \
# 0      Pro-Clip USA are garbage. They claim they don’...
# 1      Drove the Q4, MB EBQ, VW ID4 &amp; LexusRZ  al...
# 2      Audi&#39;s EV&#39;s look great, but have falle...
# 3      38 minutes from 5% to 80% is slow. The Kia and...
# 4      I normally find that sponsor placement to be a...
# ...                                                  ...
# 17716  Just want to point out that VWs have historica...
# 17717  Come on Autobytel. This model tested is not a ...
# 17718  The title of the video says 2023 but the vehic...
# 17719  From a personal perspective this is a horrible...
# 17720  Good review. I did some comparison with Tesla ...
#
#                                                  Replies  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 17716                                               None
# 17717  ['This fawning review does not describe the 20...
# 17718                                               None
# 17719  ['Given that this is made in America and quali...
# 17720  ['Volkswagens build quality is probably light ...
#
#                                              Video Title  \
# 0      The 2022 Audi Q4 E-Tron Is Audi’s New Tesla-Fi...
# 1      The 2022 Audi Q4 E-Tron Is Audi’s New Tesla-Fi...
# 2      The 2022 Audi Q4 E-Tron Is Audi’s New Tesla-Fi...
# 3      The 2022 Audi Q4 E-Tron Is Audi’s New Tesla-Fi...
# 4      The 2022 Audi Q4 E-Tron Is Audi’s New Tesla-Fi...
# ...                                                  ...
# 17716      2023 VW ID4 AWD Pro S: Is The ID.4 A Good EV?
# 17717                                2023 VW ID 4 Review
# 17718                                2023 VW ID 4 Review
# 17719                                2023 VW ID 4 Review
# 17720  2023 Volkswagen ID4 Pro S Full Review! - Bette...
#
#                                                URL  Word Count
# 0      https://www.youtube.com/watch?v=8XJeVK0_iM8          60
# 1      https://www.youtube.com/watch?v=8XJeVK0_iM8          57
# 2      https://www.youtube.com/watch?v=8XJeVK0_iM8         114
# 3      https://www.youtube.com/watch?v=8XJeVK0_iM8          48
# 4      https://www.youtube.com/watch?v=8XJeVK0_iM8          93
# ...                                            ...         ...
# 17716  https://www.youtube.com/watch?v=nAwUkLp7T9A          96
# 17717  https://www.youtube.com/watch?v=mtejBVOYhFY          54
# 17718  https://www.youtube.com/watch?v=mtejBVOYhFY          91
# 17719  https://www.youtube.com/watch?v=mtejBVOYhFY          46
# 17720  https://www.youtube.com/watch?v=F-cRYHlD5sY          63
#
# [17721 rows x 9 columns]

# %%
df_final['Make'].value_counts()
# Out:
# Lucid            1951
# Ford             1733
# Rivian           1550
# Tesla            1333
# Bmw              1252
# Mercedes-benz    1211
# Hyundai          1013
# Kia               944
# Audi              757
# Mazda             737
# Polestar          735
# Gmc               672
# Genesis           629
# Cadillac          629
# Nissan            581
# Toyota            467
# Subaru            412
# Chevrolet         401
# Volvo             310
# Jaguar            179
# Volkswagen         84
# Porsche            72
# Mini               69
# Name: Make, dtype: int64

# %% [raw]
# DEBUG
# Check if all replies which are list of lists + comments add up to total comments in the YT Video.
# [len(i) for i in list(df.loc[df["Replies"] != 'None']['Replies'])]
